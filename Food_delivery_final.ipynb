# %%
class Food():
    def __init__(self,name,phone,email,address,password,admin_details,user_details):
        self.name= name 
        self.phone= phone 
        self.email = email
        self.address = address
        self.password = password 
        self.admin_details = {}
        self.user_details = {}
    
    def admin_signup(self):
        global admin_details
        print("Enter your details to get registered: ")
        name=input("Enter your Full Name: ")
        phone= input("Enter your phone number: ")
        password=input("Enter a new password: ")
        ad_details=[name,phone,password]
        admin_details={'name':name,'phone':phone,'password':password}
        print(admin_details)
        
    def admin_login(self):
        name_check = admin_details['name']
        pass_check = admin_details['password']
        t='st'
        you = input("Enter you name: ")
        if you == name_check:
            pas = input("Enter your password: ")
            if pas == pass_check:
                print('Correct password')
                t = "correct"
                return t
            else:
                print("Re-Enter correct password")
                t = "st"
                return 
        else:
            print('Re-Enter registered user name')
            t= "st"
            return t
    
    def user_signup(self):
        global user_details
        print("Enter your details to get registered: ")
        name=input("Enter your Full Name: ")
        phone = input("Enter your phone number: ")
        email = input("Enter your email address: ")
        address = input("Enter your address: ")
        password = input("Enter a new password: ")
        usa_details=[name,phone,email,address,password]
        #print(usa_details)
        user_details={'name':name,'phone':phone,'email':email,'address':address,'password':password}
        print(user_details) 
            
    def user_login(self):
        t=0
        uname_check = user_details['name']
        upass_check = user_details['password'] 
        t='st'
        you = input("Enter you name: ")
        if you == uname_check:
            pas = input("Enter your password: ")
            if pas == upass_check:
                print('Correct password')
                t = 1
                return t
            else:
                print("Re-Enter correct password")
                t = 0
                return 
        else:
            print('Re-Enter registered user name')
            t= 0
            return t
        
    def update_profile(self):
        global user_details
        print("Lets update your details!")
        name=input("Enter your updated Full Name: ")
        phone = input("Enter your updated phone number: ")
        email = input("Enter your updated email address: ")
        address = input("Enter your updated address: ")
        password = input("Enter a updated new password: ")
        user_details={'name': name,'phone':phone,'email':email,'address':address,'password':password}
    
    def show_menu(self):
        print("Our Menu is !!")
        for i in range(0,len(l)):
            print(f"{l[i][0]}. {l[i][1]} ({l[i][2]}) {[l[i][3]]}")
        
    def add_new_menu_item(self):
        global l
        print("Enter the food items you want to add ")
        foodId = len(l)+1
        name =input("Enter the new food name: ")
        print("Somee Units you can use example: '100ml for liquids', '250gm for weight', '4pieces per peice'")
        quantity = input("Enter the food quantity with  units: ")
        price = input("Enter the price: ")
        discount = input("Enter the discount: ") 
        stock = input("Enter the stock: ")
        menu=[foodId,name,quantity,'INR'+' '+price,stock]
        l.append(menu)
  
    def stock(self):
        for i in range(len(l)):
            print(l[i])
    
    def edit_food_item(self):
        print("Editing the  the food item in the list")
        print(f"Food ID is from 1-{len(l)}")
        rid= int(input("Enter the food ID of the food you want edit: "))
        name=input("Enter the new name to food item")
        print("Somee Units you can use example: '100ml for liquids', '250gm for weight', '4pieces per peice'")
        quantity = input("Enter the food quantity with  units: ")
        price = input("Enter the price: ")
        stock = input("Enter the stock: ")
        upa=[rid,name,quantity,'INR'+' '+price,stock]
        for o in range(0,len(l)-1):
            t=l[o][0]
            if rid == t:
                 l[o]=upa       
        print("Food list is edited")  
        for i in range(0,len(l)):
            for j in range(0,len(l)):
                l[j][0] =j+1    
            print(f"{l[i][0]}. {l[i][1]} ({l[i][2]}) {[l[i][3]]} {l[i][4]}")
   
    def view_food_item_list(self):        
        for i in range(len(l)):
            print(i+1,l[i][1])


    def remove_menu_item(self):
        print("Lets delete the food item you dont wnat in the list")
        print(f"Food ID is from 1-{len(l)}")
        rid= int(input("Enter the food ID of the food you want delete: "))
        for o in range(0,len(l)-1):
            t=l[o][0]
            if rid == t:
                l.remove(l[o])        
        print("FoodId is updated")  
        for i in range(0,len(l)):
            for j in range(0,len(l)):
                l[j][0] =j+1    
            print(f"{l[i][0]}. {l[i][1]} ({l[i][2]}) {[l[i][3]]}")        
                   
    
    def order_history(self):
        sa=order_history
        for i in range(0,len(sa)):
            print(sa[i])   
            
    def place_new_order(self):
        tempa=[]
        zampa=[]
        order= input("Enter the item you want to order: ")
        order_list=list(order.split(','))
        for i in range(0,len(order_list)):
            for j in range(0,len(l)):
                if order_list[i] == str(l[j][0]):
                    print(l[j][0:-1])
                    str(tempa.append(l[j][0:-1])) 
                    x,z= l[j][2],l[j][-1]
                    y=x.split()
                    stock=int(z)-int(y[0])
                    l[j][-1]=stock
                    
        con=int(input("Do you want to place order \n1.Yes Confirm \n2.No Cancel"))
        if con == 1:
            str(order_history.append(tempa))
        else:
            print("Your order is not confirmed")
            pass

# %%
l=[[1, 'Tandoori Chicken','4 pieces','INR 240','48'],[2,'Vegan Burger', '1 Piece', 'INR 320','12'],[3,'Truffle Cake' ,'500 gm','INR 900','5000']]
order_history = []
u1=Food('name1','phone','email','address','password','admin_details','user_details')

# %%
print('Welcome to your Food App')
while True:
    choice = int(input("Who are you   \n1. Admin \n2. User \n3. Exit"))
    if choice == 1:
        print("Hey Mr.Admin ")
        while True:
            ch1 = int(input("Enter the choice:   \n1. New Admin  \n2. Already Admin  \n0. Exit"))
            if ch1 == 1:
                print("Admin lets get you registered: ")
                u1.admin_signup()
            elif ch1 == 2:
                print("Admin Enter your deatils:")
                u1.admin_login()
                while True:
                    ch2 = int(input("Enter the choice:   \n1. Add new food items  \n2. Stock \n3. Edit food items \n4. View all food items \n5. Remove item from menu \n0. Exit"))
                    if ch2 == 1:
                        print("Lets add new item: ")
                        u1.add_new_menu_item()
                    elif ch2 == 2:
                        print("Here is the stock available:")
                        u1.stock()
                    elif ch2 == 3:
                        print("Edit the food item you want to edit in the list:")
                        u1.edit_food_item()
                    elif ch2 == 4:
                        print("View all food items ")
                        u1.view_food_item_list()
                    elif ch2 == 5:
                        print("Remove item from list ")
                        u1.remove_menu_item()    
                    elif ch2 == 0:
                        break
                    else:
                        print("Enter desired Input!")
                
           
            elif ch1==0:
                break
            else:
                print("Enter desired Input!")
    elif choice==2:
        print("We are happy to see you back ")
        while True:
            ch1 = int(input("Enter the choice:   \n1. New User  \n2. Already User  \n0. Exit"))
            if ch1 == 1:
                print("Hey lets get you registered: ")
                u1.user_signup()
            elif ch1 == 2:
                print("Enter your deatils to proceed :")
                u1.user_login()
                while True:
                    ch2 = int(input("Enter the choice:   \n1. Place New Order  \n2. Order History \n3. Update Profile  \n0. Exit"))
                    if ch2 == 1:
                        print("Lets place Order: ")
                        while True:
                            ch3 = int(input("Enter the choice:   \n1. Show Menu  \n2. Select Item to Order  \n0. Exit"))
                            if ch3 == 1:
                                print("Our Menu: ") 
                                u1.show_menu()
                            elif ch3 == 2:
                                print("Select Item to order ")
                                u1.place_new_order()  
                            elif ch3 == 0:
                                break
                            else:
                                print("Enter desired Input!")
                        
                    elif ch2 == 2:
                        print("Your order history:")
                        u1.order_history()
                    elif ch2 == 3:
                        print("Update Profile")
                        u1.update_profile()   
                    elif ch2 == 0:
                        break
                    else:
                        print("Enter desired Input!")
                
            elif ch1==0:
                    break
            else:
                print("Enter desired Input!")     
    elif choice == 0:
        break
    else:
        print("Enter desired Input!")
